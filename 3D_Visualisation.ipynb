# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import skimage
from skimage import io
from skimage import viewer
from skimage.measure import label, regionprops
# Out:
# D:\Programmes\Anaconda3\lib\site-packages\skimage\viewer\utils\__init__.py:1: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   from .core import *

# %%
adipo = io.imread("Img/crop1_adipo.tif", plugin="tifffile")

# %%
np.shape(adipo)
# Out:
# (59, 1484, 8400)

# %%
plt.figure(figsize=(30,10))
plt.imshow(adipo[25,:,:])
plt.show()

# %%
# Plot des centroides en 3D

# fig, ax = plt.subplots(subplot_kw={"projection" : "3d"})
#fig.set(figheight = 10)
#fig.set(figwidth = 20)
#surf = ax.Axes3D(seg, seg, seg, cmap = plt.cm.inferno)
#
#plt.plot(x_c,y_c, '.r', markersize = 5)
#plt.show()
